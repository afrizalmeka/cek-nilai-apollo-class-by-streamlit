# %%
import pandas as pd

# %%
dir = "/Users/afrizalmulyana/Library/CloudStorage/OneDrive-PTORBITVENTURAINODNESIA/Afrizal Meka/Project Pribadi/aplikasi-cek-nilai-posttest/database/database_apollo_class.xlsx"
df1 = pd.read_excel(dir, sheet_name="intro_ai")

# %%
df2 = pd.read_excel(dir, sheet_name="python")
df2 = df2.drop(['nama'], axis=1)

df3 = pd.read_excel(dir, sheet_name="siklus_ai")
df3 = df3.drop(['nama'], axis=1)

df4 = pd.read_excel(dir, sheet_name="intro_ml")
df4 = df4.drop(['nama'], axis=1)

df_final = pd.concat([df1, df2, df3, df4], axis=1)

# %%
df_final
# Out:
#                           nama  id_msib          nohp  nilai_intro_to_ai_1  \
# 0     Adi Mulya Hyoga Pramesta  3725349   81392079914                  100
# 1             Ahmad Imam Khofi  3801595   89524253715                  100
# 2        Ahmad Malikhul Khakim  3832337   85712555526                  100
# 3            Bagus Rifqi Ridho  3763981   85161382552                  100
# 4             Bima Aji Maulana  3852379   87714476866                  100
# 5            Christopher Prima  3845534   82243039103                  100
# 6           Dhiya Arwa Fadhila  3841158  895422462944                  100
# 7                   Dinda Arum  3788761   82185511649                  100
# 8          Dinda Regina Nofiar  3346764   85156045861                  100
# 9                 Faishal Bahy  3447291   82260368898                  100
# 10       Faqih Azka Ash-Shidqi  3841917   82118045113                  100
# 11    Fiyandhika Ridho Pratama  3854585   82348877452                  100
# 12      Hanin Atika Nurussyifa  3623287   85703598708                  100
# 13          Khomsatun Natasyah  3439592   85866040215                  100
# 14       Lathifah Melita Santi  3183443   82135254500                  100
# 15               Latifa Rachma  3761118   81548882108                  100
# 16            Michael Setiawan  3842035   89673942141                  100
# 17  Muhammad Raihan Firmansyah  3762472   85803737732                  100
# 18      Muhammad Ridho Heralti  3843259   85760004087                  100
# 19    Muhammad Rifki Kurniawan  3813513   85291378856                  100
# 20              Mutia Angraini  3643895   81328256132                  100
# 21              Nadiyah Saidah  3806913  895325028877                  100
# 22               Nik Nor Allia  3849134   85718802418                  100
# 23       Nur Cahyo Tio Nugroho  3735191   81330435792                  100
# 24              Rico Kurniawan  3842455   83162498235                  100
# 25       Rizqy Ichlasul Amalia  3299393   89506117922                  100
# 26         Rousyan Afkar Irbah  3623281   81213145463                  100
# 27           Sofi Anggi Astuti  3830944   89647681473                  100
# 28               Wiyenti Halim  3510247  895399776240                  100
# 29                     Dummy 1  3000001   82225700071                   70
# 30                     Dummy 2  3000002   82225700071                   70
#
#     nilai_intro_to_ai_2  nilai_intro_to_ai_3  nilai_intro_to_ai_4  \
# 0                    85                  100                  100
# 1                    85                  100                  100
# 2                   100                  100                  100
# 3                   100                  100                  100
# 4                   100                  100                  100
# 5                   100                   90                  100
# 6                   100                  100                  100
# 7                   100                  100                  100
# 8                    85                  100                  100
# 9                   100                  100                  100
# 10                  100                  100                  100
# 11                  100                   95                  100
# 12                   85                  100                  100
# 13                  100                  100                  100
# 14                  100                   90                  100
# 15                  100                  100                  100
# 16                  100                  100                  100
# 17                  100                  100                  100
# 18                  100                  100                  100
# 19                  100                  100                  100
# 20                  100                  100                  100
# 21                  100                  100                  100
# 22                  100                  100                  100
# 23                  100                  100                  100
# 24                  100                  100                  100
# 25                  100                  100                  100
# 26                   85                  100                  100
# 27                  100                  100                  100
# 28                  100                  100                  100
# 29                   70                   70                   70
# 30                   70                   70                   70
#
#     nilai_intro_to_ai_5  absen_intro_ai_1 absen_intro_ai_2  ...  absen_ml_2  \
# 0                    90                 1                1  ...           1
# 1                    85                 1                1  ...           1
# 2                    90                 1                1  ...           K
# 3                    85                 1                1  ...           K
# 4                    95                 1                1  ...           1
# 5                    85                 1                1  ...           1
# 6                    85                 1                1  ...           1
# 7                    95                 1                1  ...           1
# 8                    90                 1                1  ...           1
# 9                    85                 1                1  ...           1
# 10                   85                 1                1  ...           1
# 11                   95                 1                1  ...           1
# 12                   90                 1                1  ...           1
# 13                   90                 1                1  ...           K
# 14                   95                 1                1  ...           1
# 15                   85                 1                1  ...           1
# 16                   95                 1                1  ...           1
# 17                   90                 1                1  ...           1
# 18                   85                 1                1  ...           1
# 19                   90                 1                1  ...           1
# 20                   90                 1                1  ...           1
# 21                   90                 1                1  ...           1
# 22                   90                 1                1  ...           1
# 23                   85                 1                1  ...           1
# 24                   90                 1                1  ...           1
# 25                   90                 1                1  ...           1
# 26                   90                 1                1  ...           1
# 27                   90                 1                1  ...           1
# 28                   90                 1                1  ...           1
# 29                   70                 0                K  ...         NaN
# 30                   70                 0                1  ...         NaN
#
#    absen_ml_3 absen_ml_4  absen_ml_5  absen_ml_6 absen_ml_7  absen_ml_8  \
# 0           1          1           1         1.0          1           1
# 1           1          1           1         1.0          1           1
# 2           1          1           1         1.0          1           1
# 3           1          0           1         1.0          K           1
# 4           1          1           1         1.0          1           1
# 5           1          1           1         1.0          K           1
# 6           1          1           1         1.0          1           1
# 7           1          1           1         1.0          1           1
# 8           K          K           K         1.0          K           K
# 9           1          1           1         1.0          1           1
# 10          K          1           1         1.0          1           1
# 11          1          1           1         1.0          1           1
# 12          1          1           1         1.0          1           1
# 13          1          1           1         1.0          1           1
# 14          0          0           1         1.0          0           0
# 15          1          1           1         1.0          1           1
# 16          1          1           1         1.0          1           1
# 17          1          1           1         1.0          1           1
# 18          1          1           1         1.0          1           1
# 19          1          1           1         1.0          1           1
# 20          0          1           0         1.0          1           K
# 21          1          K           1         1.0          1           1
# 22          1          1           1         1.0          1           1
# 23          1          1           1         1.0          1           1
# 24          1          1           1         1.0          1           1
# 25          1          K           1         1.0          1           1
# 26          1          1           1         1.0          1           1
# 27          1          1           1         1.0          1           1
# 28          1          K           1         1.0          1           1
# 29        NaN        NaN         NaN         NaN        NaN         NaN
# 30        NaN        NaN         NaN         NaN        NaN         NaN
#
#     posttest_ml  final_ml  alphabet_ml
# 0         33.33     73.33            B
# 1         40.00     76.00            B
# 2         60.00     80.25            A
# 3         33.33     58.33            C
# 4         33.33     73.33            B
# 5         26.67     56.63            C
# 6         33.33     71.62            B
# 7         46.67     78.67            B
# 8          6.67     43.92            D
# 9         33.33     71.62            B
# 10        40.00     72.25            B
# 11        20.00     66.29            C
# 12        40.00     76.00            B
# 13        26.67     63.17            C
# 14        20.00     32.11            E
# 15        33.33     73.33            B
# 16        93.33     97.33            A
# 17        86.67     94.67            A
# 18        73.33     89.33            A
# 19        33.33     73.33            B
# 20        33.33     62.08            C
# 21        26.67     66.92            C
# 22        26.67     68.95            C
# 23        86.67     94.67            A
# 24        53.33     79.62            B
# 25        46.67     74.92            B
# 26        13.33     65.33            C
# 27        66.67     86.67            A
# 28        26.67     65.20            C
# 29          NaN       NaN          NaN
# 30          NaN       NaN          NaN
#
# [31 rows x 63 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nama                 31 non-null     object
#  1   id_msib              31 non-null     int64
#  2   univ                 31 non-null     object
#  3   prodi                31 non-null     object
#  4   nohp                 31 non-null     int64
#  5   nilai_intro_to_ai_1  31 non-null     int64
#  6   nilai_intro_to_ai_2  31 non-null     int64
#  7   nilai_intro_to_ai_3  31 non-null     int64
#  8   nilai_intro_to_ai_4  31 non-null     int64
#  9   nilai_intro_to_ai_5  31 non-null     int64
#  10  absen_intro_ai_1     31 non-null     int64
#  11  absen_intro_ai_2     31 non-null     object
#  12  absen_intro_ai_3     31 non-null     int64
#  13  absen_intro_ai_4     31 non-null     object
#  14  absen_intro_ai_5     31 non-null     object
#  15  posttest_intro_ai    31 non-null     int64
#  16  final_intro_ai       29 non-null     float64
#  17  alphabet_intro_ai    31 non-null     object
#  18  nilai_python_1       29 non-null     float64
#  19  nilai_python_2       29 non-null     float64
#  20  nilai_python_3       29 non-null     float64
#  21  nilai_python_4       29 non-null     float64
#  22  nilai_python_5       29 non-null     float64
#  23  nilai_python_6       29 non-null     float64
#  24  nilai_python_7       29 non-null     float64
#  25  nilai_python_8       29 non-null     float64
#  26  posttest_python      29 non-null     float64
#  27  final_python         29 non-null     float64
#  28  alphabet_python      31 non-null     object
#  29  ds                   31 non-null     int64
#  30  nlp                  31 non-null     int64
#  31  cv                   31 non-null     int64
#  32  tech                 31 non-null     int64
#  33  sks                  31 non-null     int64
# dtypes: float64(11), int64(15), object(8)
# memory usage: 8.4+ KB

# %%
absen_intro_ai_1 = df['absen_intro_ai_1'][0]
absen_intro_ai_1
# Out:
# 1

# %%
status_absen = {1 : 'Hadir', 0 : 'Tidak Hadir', 'K' : 'Durasi Kurang'}

absen_intro_ai_1 = status_absen[absen_intro_ai_1]
absen_intro_ai_1
# Out:
# 'Tidak Hadir'

# %%
df['nama'] = df['nama'].str.lower()
df['univ'] = df['univ'].str.lower()
df['prodi'] = df['prodi'].str.lower()

# %%
size = df.shape
size = size[0]
size
# Out:
# 29

# %%
input_nama = str(input("nama : ")).lower()

size = df.shape
size = size[0] - 1
ds = '0'
nlp = '0'
cv = '0'
tech = '0'

for data in df.index:
    name = df['nama'][data]
    
    if input_nama == name:
        ds.append(df['ds'][x])
        nlp.append(df['nlp'][x])
        cv.append(df['cv'][x])
        tech.append(df['tech'][x])
        break
    
    elif data == size:
        print("data tidak ditemukan")
        
print(ds)
# Out:
# nama : shi jack
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 10>()
#      11 name = df['nama'][data]
#      13 if input_nama == name:
# ---> 14     ds.append(df['ds'][x])
#      15     nlp.append(df['nlp'][x])
#      16     cv.append(df['cv'][x])
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# Define a dictionary containing students data
data = {'Name': ['Ankit', 'Amit',
                 'Aishwarya', 'Priyanka'],
        'Age': [21, 19, 20, 18],
        'Stream': ['Math', 'Commerce',
                   'Arts', 'Biology'],
        'Percentage': [88, 92, 95, 70]}
  
# Convert the dictionary into DataFrame
df2 = pd.DataFrame(data, columns=['Name', 'Age', 
                                 'Stream', 'Percentage'])
  
print("Given Dataframe :\n", df2)
  
print("\nIterating over rows using index attribute :\n")
  
# iterate through each row and select
# 'Name' and 'Stream' column respectively.
for ind in df2.index:
    name = df2['Name'][ind]
    if name == 'Amit':
        print(df2['Name'][ind], df2['Stream'][ind])
# Out:
# Given Dataframe :
#          Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20      Arts          95
# 3   Priyanka   18   Biology          70
#
# Iterating over rows using index attribute :
#
# Amit Commerce

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 4bfe3d07b4858144c219b9346329027024102ab6
# python           : 3.9.12.final.0
# python-bits      : 64
# OS               : Darwin
# OS-release       : 22.1.0
# Version          : Darwin Kernel Version 22.1.0: Sun Oct  9 20:15:52 PDT 2022; root:xnu-8792.41.9~2/RELEASE_ARM64_T8112
# machine          : x86_64
# processor        : i386
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.UTF-8
#
# pandas           : 1.4.2
# numpy            : 1.21.5
# pytz             : 2021.3
# dateutil         : 2.8.2
# pip              : 21.2.4
# setuptools       : 61.2.0
# Cython           : 0.29.28
# pytest           : 7.1.1
# hypothesis       : None
# sphinx           : 4.4.0
# blosc            : None
# feather          : None
# xlsxwriter       : 3.0.3
# lxml.etree       : 4.8.0
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.1.2
# IPython          : 8.2.0
# pandas_datareader: None
# bs4              : 4.11.1
# bottleneck       : 1.3.4
# brotli           :
# fastparquet      : None
# fsspec           : 2022.02.0
# gcsfs            : None
# markupsafe       : 2.0.1
# matplotlib       : 3.5.1
# numba            : 0.55.1
# numexpr          : 2.8.1
# odfpy            : None
# openpyxl         : 3.0.9
# pandas_gbq       : None
# pyarrow          : None
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.7.3
# snappy           :
# sqlalchemy       : 1.4.32
# tables           : 3.6.1
# tabulate         : 0.8.9
# xarray           : 0.20.1
# xlrd             : 2.0.1
# xlwt             : None
# zstandard        : None
